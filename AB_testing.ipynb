# %% [markdown]
# # 13.04.23 A/B тестирование

# %% [markdown]
# Задача: вы проводите A/B-тестирование, чтобы проверить, какой вариант сайта приводит к большей конверсии. Вы набрали 10000 участников в каждую группу. Результаты получились следующие: в экспериментальной группе (вариант B) заказали продукт 100 человек, в контрольной (вариант А) -- 10 Какой вариант стоит предпочесть? Почему?

# %% [markdown]
# Н0: Между вариантами есть разница.

# %% [markdown]
# Первый вариант:

# %%
#подгружаю библиотеки
import math
import random
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

# %%
n_experiment = 10000
n_control = 10000
success_experiment = 100
success_control = 10

# %%
p_experiment = success_experiment / n_experiment
p_control = success_control / n_control

# %%
se_experiment_sq = (p_experiment * (1 - p_experiment)) / n_experiment
se_control_sq = (p_control * (1 - p_control)) / n_control

# %%
z = (p_experiment - p_control) / (math.sqrt(se_experiment_sq + se_control_sq))
z
# Out:
# 8.620832027071174

# %%
pValue = scipy.stats.norm.sf(abs(z))*2
pValue
# Out:
# 6.646935402107015e-18

# %% [markdown]
# Смотрю долю заказов в каждой группе:

# %%
print (p_experiment , p_control)
# Out:
# 0.01 0.001

# %% [markdown]
# Вывод: результат статистически значим, между вариантами есть разница и побеждает вариант B. То есть дизайн, который тестировался в экспериментальной группе проявил себя лучше.

# %% [markdown]
# Второй вариант:

# %%
success_experiment2 = 110
success_control2 = 100

# %%
p_experiment2 = success_experiment2 / n_experiment
p_control2 = success_control2 / n_control

# %%
se_experiment_sq2 = (p_experiment2 * (1 - p_experiment2)) / n_experiment
se_control_sq2 = (p_control2 * (1 - p_control2)) / n_control

# %%
z2 = (p_experiment2 - p_control2) / (math.sqrt(se_experiment_sq2 + se_control_sq2))
z2
# Out:
# 0.6937255317022565

# %%
pValue2 = scipy.stats.norm.sf(abs(z2))*2
pValue2
# Out:
# 0.4878543512514194

# %% [markdown]
# Вывод: Поскольку наше p-value=0,49 намного выше нашего порога α=0,05, мы не можем отвергнуть нулевую гипотезу. Результат не статистически значим. Разницы между вариантами нет.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c2f82967-7817-4c28-b57c-e4c6e3b8ad5f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
